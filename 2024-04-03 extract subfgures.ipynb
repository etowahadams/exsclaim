# %%
import polars as pl
import os
import cv2
from figure import detect_subfigure_labels, dummy_detect_label_letter, classify_subfigures, save_subfigures, show_image_with_bboxes

# %%
import re

def count_subfigures(caption):
    patterns = [
        r"(?:^|\.\s)([a-z](?=,))", # a, 
        r"(?:^|\.\s|,\s)([a-z])\.", # a.
        r"(?:^|\.\s|,\s)\(([a-z])\)", # (a)
        r"\(([a-z])-([a-z])\)", # (a-b)
        r"\(([a-z])\sand\s([a-z])\)", # (a and b)
        r"\,([a-z])\,", # ,a,
        r"(?:^|\.\s)[a-z]–([a-z])" # a–b -- captures the second one
    ]
    all_patterns = r"|".join(patterns)
    matches = re.finditer(all_patterns, caption, re.IGNORECASE)
    letters = []
    for match in matches:
        groups = [group.lower() for group in match.groups() if group is not None]
        letters.append(max(groups))

    if len(letters) == 0:
        return 1
    return ord(max(letters)) - ord('a') + 1

sample_caption = "a, UMAP shows CTB and STB nuclei profiled with integration of snRNA-seq and snATAC-seq in early pregnancy. b, Heatmap shows pseudotime ordering of the 23,746 DARs in early pregnancy (left). Zoomed-in genomic tracks show the cis-element accessibility of representative genes. The normalized accessibility of DARs is presented with color intensities. c, TF-mining heatmap shows candidate master TFs of each nucleus type. The NES and expression z score are presented with dot color and dot size, respectively. Dots with bold edges show selected TFs used for network construction. d, Regulatory networks with three layers (TF, cis-element and target gene) represent the cis-regulatory architecture covering the complete STB differentiation process. The gene percentage, peak accessibility and gene expression score are presented with circle sizes, edge width and color intensities, respectively. e, smFISH staining (left) and fluorescence intensities (right) show the colocalization of TFs (STAT5A and FOSL2) and representative genes (PAPPA and FLT1) of eSTB mature 1 and eSTB mature 2. hCG, STB marker. The white dotted lines show the outline of CTB. The white lines represent the plotted tracks of fluorescence intensity. f, UMAP shows CTB and STB nuclei profiled with integration of snRNA-seq of STB-CT30, STB-BL and placenta villi in early pregnancy. g, Heatmaps show marker gene expression in STB-BL, STB-CT30 and placental villi in early pregnancy. The expression levels are presented with color intensities. Binarized gene expression levels (positive or negative) are calculated and visualized beside heatmaps for the two marker genes, PAPPA and FLT1. h, Pseudotime ordering shows three differential trajectories of CTB and STB nuclei (upper left). The differentiation time is presented with color intensities. Quantitative classifications for each cluster (upper right) and specific pseudotime of cluster 9 and cluster 7 on the integrated UMAP (bottom) are shown. i, Heatmap shows the different expression patterns of marker genes, master TFs and representative hormones among in vitro trophoblast models and in vivo placental villi in early pregnancy. The z scores are presented with color intensities. Examples of genes with similar expression patterns are highlighted in bold black, and those with different patterns are colored in red."
print(count_subfigures(sample_caption))
# Out:
# 9

# %%
image_folder = "imgs"
image_files = [os.path.join(image_folder, file) for file in os.listdir(image_folder) if file.endswith((".png", ".jpg", ".gif"))]

image_files = ["imgs/10335933_Fig5.jpg"]
for image_file in image_files:
    bounding_boxes = detect_subfigure_labels(image_file)
    # show_image_with_bboxes(image_file, bounding_boxes)
    subfigure_info, concate_img = dummy_detect_label_letter(image_file, bounding_boxes)
    # show_labels_on_image(image_file, subfigure_info, save=False, show=True)
    figure_json = classify_subfigures(image_file, subfigure_info, concate_img)
    save_subfigures(image_file, figure_json, out_dir="test")
# Out:
# image 1/1 /Users/etowah/projects/forks/exsclaim/imgs/10335933_Fig5.jpg: 640x544 13 labels, 146.3ms
# Speed: 5.6ms preprocess, 146.3ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 544)
# /Users/etowah/projects/forks/exsclaim/figures/models/yolo_layer.py:374: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:212.)
#   x_shift = dtype(np.broadcast_to(

# %%
def non_max_suppression(boxes, scores, threshold):
    """
    Perform non-max suppression on a set of bounding boxes and corresponding scores.

    :param boxes: a list of bounding boxes in the format [xmin, ymin, xmax, ymax]
    :param scores: a list of corresponding scores
    :param threshold: the IoU (intersection-over-union) threshold for merging bounding boxes
    :return: a list of indices of the boxes to keep after non-max suppression
    """
    # Sort the boxes by score in descending order
    order = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)
    keep = []
    while order:
        i = order.pop(0)
        keep.append(i)
        for j in order:
            # Calculate the IoU between the two boxes
            intersection = max(0, min(boxes[i][2], boxes[j][2]) - max(boxes[i][0], boxes[j][0])) * \
                           max(0, min(boxes[i][3], boxes[j][3]) - max(boxes[i][1], boxes[j][1]))
            union = (boxes[i][2] - boxes[i][0]) * (boxes[i][3] - boxes[i][1]) + \
                    (boxes[j][2] - boxes[j][0]) * (boxes[j][3] - boxes[j][1]) - intersection
            iou = intersection / union

            # Remove boxes with IoU greater than the threshold
            if iou > threshold:
                order.remove(j)
    return keep

# %%
figure_data = pl.read_parquet("figure_data.parquet")
out_dir = "test"
failed = []

for row in figure_data.rows():
    base_dir = "/Users/etowah/projects/PMC-figure-downloader/img"
    # Access the values of each column in the current row
    figure_name = f"{row[0]}_{row[1]}"
    img_path = f"{base_dir}/{figure_name}.jpg"
    caption = row[4]
    n_subfigures = count_subfigures(caption)
    print(n_subfigures)
    if n_subfigures == 1:
        print(caption)
        image = cv2.imread(img_path)
        cv2.imwrite(f"{out_dir}/{figure_name}.jpg", image)
    else:
        bboxes = detect_subfigure_labels(img_path)
        scores = [box[4] for box in bboxes]
        keep = non_max_suppression(bboxes, scores, 0.5)
        bounding_boxes = [bboxes[i] for i in keep]
        # show_image_with_bboxes(image_file, bounding_boxes)
        if (len(bounding_boxes) != n_subfigures):
            print(f"Subfigure count mismatch: {len(bounding_boxes)} detected, {n_subfigures} expected")
            # show_image_with_bboxes(img_path, bounding_boxes)
            failed.append([row[0], row[1]])
            continue
        subfigure_info, concate_img = dummy_detect_label_letter(img_path, bounding_boxes)
        # show_labels_on_image(image_file, subfigure_info, save=False, show=True)
        figure_json = classify_subfigures(img_path, subfigure_info, concate_img)
        save_subfigures(img_path, figure_json, out_dir=out_dir)

    
print(failed)
# Out:
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig1.jpg: 640x544 5 labels, 77.1ms
# Speed: 2.2ms preprocess, 77.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig2.jpg: 640x608 5 labels, 81.2ms
# Speed: 2.3ms preprocess, 81.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig3.jpg: 576x640 7 labels, 82.5ms
# Speed: 2.3ms preprocess, 82.5ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
# Subfigure count mismatch: 7 detected, 6 expected
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig4.jpg: 640x640 4 labels, 104.3ms
# Speed: 2.3ms preprocess, 104.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig5.jpg: 640x544 5 labels, 78.5ms
# Speed: 2.0ms preprocess, 78.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig6.jpg: 640x320 4 labels, 62.6ms
# Speed: 1.4ms preprocess, 62.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 320)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig7.jpg: 640x640 6 labels, 106.8ms
# Speed: 2.6ms preprocess, 106.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1
# Relative expression in each cell type was calculated based on DESeq2-normalized counts from 6-8 control donors, and was log2-transformed for visualization (see Methods). The marker genes specific for each interneuron subtype were selected based on single-nucleus RNA sequencing (snRNA-seq) data19. The FANS-isolated ETV1 + TAC3- population of Parvalbumin-expressing interneuron nuclei most likely captured both the major PVALB+ interneuron population and the related smaller PVALB + TH+ interneuron population defined as a separate subtype in snRNA-seq analysis19.
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig9.jpg: 640x640 3 labels, 92.4ms
# Speed: 2.3ms preprocess, 92.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig10.jpg: 640x512 4 labels, 102.2ms
# Speed: 2.2ms preprocess, 102.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# 1
# a, Heatmaps depict log2-transformed relative expression in each cell type, calculated based on the mean of DESeq2-normalized counts from 7-8 control donors. Genes identified as HD age at onset-modifying candidates are marked with an asterisk. Genes known to influence CAG tract instability in HD mouse models are marked with an arrowhead. b-d, Relative levels of MSH2 (b), MSH3 (c) and FAN1 (d) transcripts in MSNs compared to interneurons, calculated with DESeq2 using cell type-specific FANS-seq data from control donors. The largest P adj. value of all MSN vs. interneuron comparisons (by DESeq2, P adjusted for multiple comparisons) is indicated for each gene. For caudate nucleus samples: n = 8 individuals for dMSNs, iMSNs, TAC3 + IN, PVALB + IN and SST + IN. For putamen samples: n = 8 individuals for dMSNs, iMSNs, TAC3 + IN, n = 7 individuals for PVALB + IN and n = 6 individuals for SST + IN.
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig12.jpg: 640x512 9 labels, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
# Subfigure count mismatch: 8 detected, 9 expected
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937393_Fig13.jpg: 544x640 4 labels, 81.7ms
# Speed: 1.9ms preprocess, 81.7ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig1.jpg: 640x512 8 labels, 72.4ms
# Speed: 1.9ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig2.jpg: 640x512 11 labels, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig3.jpg: 640x608 5 labels, 65.0ms
# Speed: 1.9ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig4.jpg: 640x416 4 labels, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 416)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig5.jpg: 576x640 4 labels, 86.7ms
# Speed: 2.4ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig6.jpg: 352x640 2 labels, 84.1ms
# Speed: 1.4ms preprocess, 84.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# 1
# Oncoprint from cBioPortal analysis of human muscle-invasive bladder cancers from The Cancer Genome Atlas bladder cancer (TCGA-BLCA) cohort showing select genes for which gain- or loss-of-function events were incorporated into the bladder urothelial LV pool.
# 1
# (a–e) Low- and high-magnification images of H&E-stained sections and high-magnification images of IHC-stained sections for GFP and pan-cytokeratin (panCK) expression depicting characteristic histologies. Scale bars = 50 µm.
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig9.jpg: 640x384 2 labels, 76.5ms
# Speed: 1.8ms preprocess, 76.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937382_Fig10.jpg: 640x480 5 labels, 68.9ms
# Speed: 1.9ms preprocess, 68.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# Subfigure count mismatch: 5 detected, 4 expected
# 1
# MuSiCal decomposes a mutation count matrix X into a signature matrix W and an exposure matrix H through four main modules: preprocessing, de novo discovery, matching and refitting, and in silico validation/optimization. The new methods implemented in each module are highlighted. Solid purple arrows represent a typical workflow of mutational signature analysis. Dashed orange arrows denote that some steps in the workflow potentially require repeating an earlier step (‘Results’).
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig2.jpg: 640x512 3 labels, 86.9ms
# Speed: 2.2ms preprocess, 86.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig3.jpg: 576x640 6 labels, 81.4ms
# Speed: 2.3ms preprocess, 81.4ms inference, 0.8ms postprocess per image at shape (1, 3, 576, 640)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig4.jpg: 544x640 3 labels, 72.7ms
# Speed: 2.2ms preprocess, 72.7ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig5.jpg: 320x640 8 labels, 56.5ms
# Speed: 1.2ms preprocess, 56.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig6.jpg: 640x512 3 labels, 73.9ms
# Speed: 1.9ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig7.jpg: 384x640 4 labels, 61.9ms
# Speed: 1.5ms preprocess, 61.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig8.jpg: 640x640 4 labels, 109.8ms
# Speed: 2.6ms preprocess, 109.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig9.jpg: 640x576 6 labels, 89.8ms
# Speed: 2.2ms preprocess, 89.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 576)
# Subfigure count mismatch: 6 detected, 2 expected
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig10.jpg: 352x640 4 labels, 60.4ms
# Speed: 1.3ms preprocess, 60.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig11.jpg: 352x640 4 labels, 54.1ms
# Speed: 1.4ms preprocess, 54.1ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig12.jpg: 576x640 4 labels, 83.5ms
# Speed: 2.2ms preprocess, 83.5ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
# 1
# a-c. An example with the PCAWG ColoRect.AdenoCA dataset to demonstrate that cohort stratification can benefit de novo signature discovery. After an initial signature discovery with the entire dataset of 60 samples, hierarchical clustering is performed using the de novo exposure matrix H, and 3 clusters are selected by the gap statistic, as shown in panel (a). The 3 clusters correspond to samples with MMRP, MMRD, and POLE mutations, respectively, as shown in panel (b). In panel (c), de novo signatures discovered from the entire dataset of 60 samples and the MMRP cluster (43 samples) are plotted, demonstrating improved sensitivity of signature discovery after cohort stratification. Specifically, 12 signatures are discovered when de novo discovery is performed with the entire dataset of 60 samples, while 11 are discovered with the MMRP cluster alone. Out of the 11 MMRP-specific signatures, only 7 are discovered before cohort stratification. Therefore, a separate run of de novo discovery with the MMRP cluster allows 4 more MMRP-specific signatures to be discovered. In panel (a), reasonable k means any k satisfying Gap(k)≥Gap(k + 1) − sk+1, where Gap(k) denotes the gap statistic (indicated by dots in the plot) and sk the standard deviation of 50 independent simulations after accounting for simulation errors (indicated by error bars in the plot). The smallest reasonable k is chosen as the optimal k. See60,61 for more details. d-f. An example with the PCAWG CNS.GBM dataset to demonstrate that outlier removal can benefit de novo signature discovery. When signature discovery is performed with the entire dataset, 4 de novo signatures are discovered, as shown in panel (d), where Signature A corresponds to SBS11 associated with temozolomide treatment. When the de novo exposures are inspected with the Gini coefficient, a single outlier sample with an exceptionally strong exposure of Signature A is detected, as shown in panel (e). After removing this outlier and rerunning signature discovery with the remaining samples, an additional signature is discovered, as shown in panel (f), demonstrating improved sensitivity.
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig14.jpg: 640x608 6 labels, 85.5ms
# Speed: 2.5ms preprocess, 85.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig15.jpg: 608x640 2 labels, 98.1ms
# Speed: 2.4ms preprocess, 98.1ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937379_Fig16.jpg: 640x640 4 labels, 89.7ms
# Speed: 2.3ms preprocess, 89.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# 1
# Exposures of SBS40 and ID5 are correlated for both MuSiCal- (top) and PCAWG-derived (middle) signature assignments in kidney and bladder cancers, which are the only tumor types where SBS40 is assigned by MuSiCal. PCAWG also assigns SBS40 in many other tumor types (bottom), where a strong correlation is not observed. Pearson correlation coefficients are shown for both absolute (left) and relative (right) exposures (normalized by mutation burden). Error bands (shaded areas) indicate 95% confidence intervals of the linear regressions.
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig1.jpg: 640x576 11 labels, 77.6ms
# Speed: 2.3ms preprocess, 77.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig2.jpg: 640x512 10 labels, 69.8ms
# Speed: 2.1ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 11
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig3.jpg: 640x480 12 labels, 77.0ms
# Speed: 2.1ms preprocess, 77.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# Subfigure count mismatch: 12 detected, 11 expected
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig4.jpg: 640x512 7 labels, 67.3ms
# Speed: 2.1ms preprocess, 67.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# 14
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig5.jpg: 640x608 15 labels, 82.4ms
# Speed: 2.3ms preprocess, 82.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
# 11
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig6.jpg: 640x544 11 labels, 78.4ms
# Speed: 3.2ms preprocess, 78.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig7.jpg: 608x640 9 labels, 114.7ms
# Speed: 2.4ms preprocess, 114.7ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig8.jpg: 640x512 10 labels, 90.0ms
# Speed: 2.1ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig9.jpg: 512x640 9 labels, 71.2ms
# Speed: 2.0ms preprocess, 71.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig10.jpg: 640x512 7 labels, 78.6ms
# Speed: 1.9ms preprocess, 78.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# Subfigure count mismatch: 7 detected, 8 expected
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig11.jpg: 608x640 3 labels, 95.3ms
# Speed: 2.3ms preprocess, 95.3ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig12.jpg: 416x640 4 labels, 74.7ms
# Speed: 1.6ms preprocess, 74.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
# Subfigure count mismatch: 4 detected, 3 expected
# 12
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig13.jpg: 640x576 12 labels, 73.4ms
# Speed: 2.4ms preprocess, 73.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 576)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig14.jpg: 640x512 9 labels, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Subfigure count mismatch: 9 detected, 8 expected
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig15.jpg: 608x640 7 labels, 92.1ms
# Speed: 2.5ms preprocess, 92.1ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937375_Fig16.jpg: 640x480 5 labels, 70.0ms
# Speed: 1.8ms preprocess, 70.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig1.jpg: 640x448 7 labels, 73.4ms
# Speed: 1.8ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 448)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig2.jpg: 512x640 3 labels, 89.9ms
# Speed: 2.0ms preprocess, 89.9ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
# 1
# The colors of the ribbon plot represent molecular categories of samples in the pAML cohort (n = 887).
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig4.jpg: 640x512 5 labels, 79.8ms
# Speed: 2.1ms preprocess, 79.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig5.jpg: 640x544 6 labels, 82.3ms
# Speed: 2.2ms preprocess, 82.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig6.jpg: 640x576 5 labels, 79.6ms
# Speed: 2.8ms preprocess, 79.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig7.jpg: 512x640 6 labels, 72.4ms
# Speed: 2.0ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig8.jpg: 640x480 7 labels, 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# 1
# Pair-wise correlation among most frequent 97 genetic alterations (n ≥ 5 in the entire cohort) from GRIN analysis and chromosomal changes (complex karyotype and monosomy 7) (a) and category-defining gene alterations (b). KMT2A-PTD (partial tandem duplication) is independently included from other KMT2A alterations, and FLT3 alterations are classified into ITD (internal tandem duplication), TKD (tyrosine kinase domain) mutations, and non-TKD mutations due to the known functional difference. Colors correspond to Pearson correlation. Statistical significance was assessed by two-sided Fisher’s exact test to calculate P values followed by the Benjamini-Hochberg adjustment for multiple testing to calculate q values (*P < 0.05, **q < 0.05).
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig10.jpg: 640x512 5 labels, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig11.jpg: 640x512 2 labels, 79.7ms
# Speed: 2.1ms preprocess, 79.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig12.jpg: 640x512 5 labels, 104.1ms
# Speed: 1.9ms preprocess, 104.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# Subfigure count mismatch: 5 detected, 4 expected
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig13.jpg: 640x480 1 label, 78.4ms
# Speed: 2.0ms preprocess, 78.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# Subfigure count mismatch: 1 detected, 2 expected
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig14.jpg: 640x544 6 labels, 82.0ms
# Speed: 2.1ms preprocess, 82.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
# Subfigure count mismatch: 6 detected, 8 expected
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig15.jpg: 640x640 4 labels, 107.1ms
# Speed: 2.4ms preprocess, 107.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig16.jpg: 640x448 5 labels, 64.5ms
# Speed: 1.9ms preprocess, 64.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 448)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864188_Fig17.jpg: 512x640 4 labels, 66.3ms
# Speed: 1.8ms preprocess, 66.3ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
# 15
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig1.jpg: 640x576 15 labels, 70.5ms
# Speed: 2.4ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig2.jpg: 640x544 8 labels, 101.5ms
# Speed: 2.1ms preprocess, 101.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
# 14
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig3.jpg: 544x640 14 labels, 79.0ms
# Speed: 1.9ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig4.jpg: 640x640 10 labels, 103.8ms
# Speed: 2.5ms preprocess, 103.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig5.jpg: 448x640 9 labels, 71.2ms
# Speed: 1.7ms preprocess, 71.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig6.jpg: 480x640 7 labels, 61.7ms
# Speed: 1.9ms preprocess, 61.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# 1
# (a) Previous mapping efforts located qRgls1 to a 1.4-Mb region on the short arm of maize chromosome 8. (b–d) Sequential fine-mapping of qRgls1 (n = 3290). The schematic diagrams to the right represent the genomic architecture of each recombinant type. The markers used in the fine-mapping are indicated, with red markers showing the limits of the qRgls1 region as defined at each fine-mapping step. The tables to the right summarize the DSI from homozygous and heterozygous backcross progeny of recombinants. Significant difference (P < 0.05) in DSI between heterozygous and homozygous offspring indicates the presence of the resistance allele at qRgls1 in the heterozygous region of their parental recombinant; otherwise, there is no qRgls1 (P > 0.05). Data are shown as means ± s.d. in (b)–(d) and the P value was determined based on two-sided Student’s t-test.
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig8.jpg: 352x640 6 labels, 64.5ms
# Speed: 1.6ms preprocess, 64.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
# Subfigure count mismatch: 6 detected, 4 expected
# 1
# Schematic diagrams of ZmWAKL (a) and ZmPR5L (b) loci, as determined by aligning the full-size complementary DNA (cDNA) with the corresponding genomic sequence. Rectangles, exons; lines, introns. The colors indicate different domains: yellow, SP (signal peptide); light orange, GUB (galacturonan-binding domain of wall-associated receptor kinase); pink, TM (transmembrane domain); blue, Ser/Thr kinase. Gray shading between the Y32 and Q11 alleles represents the syntenic region; red lines denote SNPs; black spaces or lines represent InDels.
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig10.jpg: 480x640 7 labels, 69.9ms
# Speed: 2.3ms preprocess, 69.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Subfigure count mismatch: 7 detected, 8 expected
# 14
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig11.jpg: 480x640 6 labels, 70.1ms
# Speed: 1.8ms preprocess, 70.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Subfigure count mismatch: 6 detected, 14 expected
# 1
# (a) Relative ZmWAKL expression in tissues collected from NIL-Q11 and NIL-Y32 plants (n = 3). (b,c) Relative expression levels of ZmWAKL in NIL-Q11 and NIL-Y32 after inoculation with C. zeina in the greenhouse (b) or field (c). (d,e) Subcellular localization of ZmWAKL in onion epidermal cells (d) and ZmWAKL-GFP overexpression transgenic plants (e). Plasmolysis was achieved by incubating cells in 0.3 g/mL sucrose for 5 min. Scale bars, 50 μm. DIC, differential interference contrast. The membrane was stained with the membrane-impermeable dye FM4-64. This experiment was repeated two times with the same results. In (a–c), values are means ± s.d., statistical significance was determined by a two-sided Student’s t-test.
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig13.jpg: 608x640 10 labels, 82.7ms
# Speed: 2.2ms preprocess, 82.7ms inference, 6.2ms postprocess per image at shape (1, 3, 608, 640)
# Subfigure count mismatch: 10 detected, 8 expected
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig14.jpg: 576x640 4 labels, 76.9ms
# Speed: 2.3ms preprocess, 76.9ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864183_Fig15.jpg: 544x640 7 labels, 74.8ms
# Speed: 5.2ms preprocess, 74.8ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
# 1
# (a) Schematic diagram of ZmRBOH4 and the sgRNA target site in the first exon for CRISPR/Cas9-mediated editing. The sequences of two homozygous knockout lines with insertion (ko #1) and deletion (ko #2) are shown. The wild-type B73 sequence is shown on top. The target sites and PAM are highlighted in red and gray, respectively, with deletions indicated by dashes. (b,c) Plant morphology (b) and height (c) of B73 and two homozygous knockout lines (n = 183). The knockout lines exhibit significantly reduced height. Scale bar, 30 cm. Data in (c) are displayed as box and whisker plots with individual data points, the asterisk denotes the mean, and the box limits indicate the interquartile range. The center line indicates the median, and different lowercase letters indicate a significant difference (P < 0.05) based on one-way ANOVA with LSD test.
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864181_Fig1.jpg: 512x640 4 labels, 73.6ms
# Speed: 1.8ms preprocess, 73.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864181_Fig2.jpg: 480x640 3 labels, 69.5ms
# Speed: 1.7ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864181_Fig3.jpg: 480x640 4 labels, 85.5ms
# Speed: 1.9ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864181_Fig4.jpg: 640x416 5 labels, 91.5ms
# Speed: 2.9ms preprocess, 91.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 416)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864181_Fig5.jpg: 544x640 4 labels, 83.1ms
# Speed: 2.2ms preprocess, 83.1ms inference, 2.6ms postprocess per image at shape (1, 3, 544, 640)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864181_Fig6.jpg: 640x512 6 labels, 85.4ms
# Speed: 2.0ms preprocess, 85.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864176_Fig1.jpg: 640x512 10 labels, 69.1ms
# Speed: 2.0ms preprocess, 69.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 512)
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864176_Fig2.jpg: 640x480 8 labels, 65.6ms
# Speed: 1.9ms preprocess, 65.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864176_Fig3.jpg: 640x512 10 labels, 72.5ms
# Speed: 2.3ms preprocess, 72.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864176_Fig4.jpg: 640x512 9 labels, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864176_Fig5.jpg: 640x448 9 labels, 74.5ms
# Speed: 2.1ms preprocess, 74.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864174_Fig1.jpg: 256x640 2 labels, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 640)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864174_Fig2.jpg: 448x640 6 labels, 67.4ms
# Speed: 1.6ms preprocess, 67.4ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864174_Fig3.jpg: 640x640 4 labels, 106.1ms
# Speed: 2.3ms preprocess, 106.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Subfigure count mismatch: 4 detected, 3 expected
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864174_Fig4.jpg: 320x640 2 labels, 57.9ms
# Speed: 1.4ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# 1
# Individual-level genotype data are subject to data sharing restrictions. SVD-based processing creates anonymous data describing variation in case genotypes without storing individual data that could be shared with no restrictions. Remote server with a pool of controls selects a set of control genotype variation matching cases, estimates allele frequency for sites to be used for association study and delivers results to the user.
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864173_Fig2.jpg: 640x544 8 labels, 79.5ms
# Speed: 2.0ms preprocess, 79.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864173_Fig3.jpg: 640x448 8 labels, 81.3ms
# Speed: 1.7ms preprocess, 81.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 448)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864173_Fig4.jpg: 640x512 5 labels, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10864173_Fig5.jpg: 576x640 6 labels, 77.2ms
# Speed: 2.3ms preprocess, 77.2ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937405_Fig1.jpg: 640x512 5 labels, 110.7ms
# Speed: 2.2ms preprocess, 110.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937405_Fig2.jpg: 640x608 8 labels, 104.1ms
# Speed: 2.8ms preprocess, 104.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937405_Fig3.jpg: 576x640 6 labels, 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 640)
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937405_Fig4.jpg: 544x640 4 labels, 89.9ms
# Speed: 2.1ms preprocess, 89.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937405_Fig5.jpg: 640x512 10 labels, 78.7ms
# Speed: 2.1ms preprocess, 78.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937405_Fig6.jpg: 640x320 8 labels, 80.1ms
# Speed: 1.4ms preprocess, 80.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 320)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig1.jpg: 608x640 3 labels, 92.0ms
# Speed: 2.3ms preprocess, 92.0ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig2.jpg: 640x512 3 labels, 80.4ms
# Speed: 1.9ms preprocess, 80.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig3.jpg: 640x608 11 labels, 91.8ms
# Speed: 2.9ms preprocess, 91.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 608)
# 23
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig4.jpg: 640x512 22 labels, 101.4ms
# Speed: 2.3ms preprocess, 101.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 512)
# Subfigure count mismatch: 22 detected, 23 expected
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig5.jpg: 640x640 4 labels, 90.5ms
# Speed: 2.4ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1
# Runtimes of BayesSpace, FICT, Giotto’s HMRF module, GraphST, MERINGUE’s spatial clustering module, SpaGCN, SpiceMix, STAGATE, nonspatial clustering (Seurat) and BANKSY for increasing cell numbers, up to 2 million cells. All methods were benchmarked on a 16-CPU 128-GB machine. Runtimes are shown up to the maximum cell number accommodated by each method, with a cutoff of 16 h.
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig7.jpg: 640x512 2 labels, 81.1ms
# Speed: 2.2ms preprocess, 81.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# 1
# a) Non-spatial and BANKSY UMAPs colored by their respective clusters, with cell type labels for BANKSY clusters. b) Spatial plots for the full dataset and a single ROI colored by BANKSY clusters. c) Spatial distribution of macrophages, with the Mac.2 cluster enriched in the submucosa. Violin plots show DE genes between the two macrophage subpopulations. Mac.1 n = 1177, Mac.2 n = 214.
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig9.jpg: 640x448 7 labels, 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
# 1
# The number of clusters was varied by adjusting parameters related to clustering resolution (number of nearest neighbors, k, in the graph for MERINGUE, and the number of clusters, N, for SpaGCN and FICT). Each column represents one clustering run for the indicated method at a given effective resolution. Blue arrows indicate the runs compared in Fig. 4. Green and red boxes indicate success and failure to identify the known neuronal or oligodendrocyte subclusters (Fig. 4; Supplementary Fig. 18). Conventional non-spatial clustering and MERINGUE (at any number of clusters) failed to separate both the oligodendrocyte subclusters and the neuronal subclusters. While Giotto separated the CA3 neurons (orange) from the somatosensory cortex neurons (brown), and at some resolutions was able to identify the fornix oligodendrocytes (dark green), it failed to identify the thalamic oligodendrocytes (purple) at all resolutions. Importantly, Giotto tended to cause clusters to form spatially disconnected groups of cells (‘patches’) that do not correspond to any known anatomical structures in the thalamus or hippocampal formation (dashed red boxes). BayesSpace merged several neuronal clusters: at N = 16 - 18, it merged the somatosensory cortex neurons with the CA3, CA1 and dentate gyrus neurons (blue clusters; all anatomical regions labeled in Fig. 4 in the main text), and at N = 19 - 20, it separated out the CA3 neurons, from the somatosensory cortex neurons, but merged the CA1 and dentate gyrus neurons. It also failed to separate out the thalamic oligodendrocytes from the fornix oligodendrocytes (red boxes around the dark green cluster).
# 1
# Similar to Extended Data Fig. 4. As before, the number of clusters was varied by adjusting parameters related to clustering resolution. Each column represents one clustering run for the indicated method at a given resolution (controlled by the number of clusters input parameter, N). Blue arrows indicate the runs compared in Fig. 4. Green and red boxes indicate success and failure (respectively) to identify the known neuronal or oligodendrocyte subclusters (Fig. 4; Supplementary Fig. 18). SpiceMix correctly separated the thalamic and fornix oligodendrocytes, merged the somatosensory cortex neurons with either the CA3 neuron (orange clusters) or the dentate gyrus neurons (brown and light green clusters). SpaGCN was able to identify the CA3 neurons, but merged the somatosensory cortex neurons with cells in the dentate gyrus (brown cluster), and was unable to separate the thalamic and fornix oligodendrocytes (red boxed green clusters). FICT, like Giotto in Extended Data Fig. 4, tended to group cells into disconnected spatial patches that do not conform to known anatomical structures (dashed red boxes), and tended to merge the dentate gyrus, CA1, CA3 and somatosensory cortex neurons into one or two clusters (light and dark blue clusters).
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig12.jpg: 640x640 3 labels, 112.9ms
# Speed: 2.4ms preprocess, 112.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937399_Fig13.jpg: 576x640 3 labels, 101.8ms
# Speed: 2.1ms preprocess, 101.8ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
# 1
# a). BANKSY UMAP and spatial plots colored by tissue segment annotations. b). BANKSY UMAP and spatial plots colored by BANKSY clusters. c). Non-spatial UMAP and spatial plots colored by non-spatial clusters. d). Comparison of BANKSY and non-spatial clusters with community domain annotations. e). Marker genes for smooth muscle and mature epithelial communities identified by BANKSY. Boxplots are colored as in (d). Center line: median, dotted line: mean, height of box: interquartile range (IQR), whiskers: 1.5 x IQR. CD66 Annotation: n = 3179 (mean = 1.47, median = 0.636) vs 6189 (mean = 0.107, median = -0.167) cells, BANKSY: n = 3435 (mean = 1.70, median = 0.935) vs 5232 (mean = -0.184, median = -0.249), aSMA BANKSY: n = 3222 (mean = 1.26, median = 1.04) vs 4826 (mean = 0.245, median = 0.138). All p-values < 2.2e-16.
# 1
# Performance of non-spatial clustering, BayesSpace and BANKSY with and without batch correction on joint clustering of spots from n = 12 DLPFC Visium datasets. ARI: adjusted Rand index. NMI: normalized mutual information. MCC: Matthew’s correlation coefficient. Center line: median, red dotted line: mean, height of box: interquartile range (IQR), whiskers: 1.5 x IQR.
# 1
# All methods were benchmarked using a NVIDIA T4 GPU with 16GB of memory. Runtimes are shown up to the maximum cell number accommodated by each method.
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig1.jpg: 640x512 7 labels, 71.2ms
# Speed: 1.9ms preprocess, 71.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 512)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig2.jpg: 640x544 8 labels, 97.2ms
# Speed: 2.1ms preprocess, 97.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
# 12
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig3.jpg: 640x544 12 labels, 89.8ms
# Speed: 2.3ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
# 11
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig4.jpg: 640x512 12 labels, 76.2ms
# Speed: 1.9ms preprocess, 76.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
# Subfigure count mismatch: 12 detected, 11 expected
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig5.jpg: 640x480 10 labels, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# 12
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig6.jpg: 640x480 13 labels, 81.8ms
# Speed: 2.1ms preprocess, 81.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig7.jpg: 640x608 9 labels, 102.3ms
# Speed: 2.8ms preprocess, 102.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig8.jpg: 640x608 8 labels, 92.6ms
# Speed: 1.9ms preprocess, 92.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 608)
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig9.jpg: 640x576 11 labels, 76.1ms
# Speed: 2.0ms preprocess, 76.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig10.jpg: 640x544 9 labels, 80.3ms
# Speed: 2.2ms preprocess, 80.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
# 8
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig11.jpg: 640x480 8 labels, 75.5ms
# Speed: 1.9ms preprocess, 75.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# 11
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig12.jpg: 640x480 11 labels, 70.2ms
# Speed: 1.8ms preprocess, 70.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig13.jpg: 640x480 5 labels, 92.9ms
# Speed: 2.2ms preprocess, 92.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Subfigure count mismatch: 5 detected, 3 expected
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig14.jpg: 640x480 6 labels, 61.1ms
# Speed: 1.9ms preprocess, 61.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig15.jpg: 448x640 5 labels, 84.4ms
# Speed: 1.8ms preprocess, 84.4ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig16.jpg: 640x608 7 labels, 81.2ms
# Speed: 2.7ms preprocess, 81.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
# Subfigure count mismatch: 7 detected, 5 expected
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig17.jpg: 640x576 5 labels, 80.9ms
# Speed: 2.2ms preprocess, 80.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 576)
# 10
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937392_Fig18.jpg: 640x480 12 labels, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# Subfigure count mismatch: 12 detected, 10 expected
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig1.jpg: 640x480 3 labels, 71.9ms
# Speed: 1.9ms preprocess, 71.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# 9
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig2.jpg: 576x640 8 labels, 89.0ms
# Speed: 2.1ms preprocess, 89.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
# Subfigure count mismatch: 7 detected, 9 expected
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig3.jpg: 224x640 5 labels, 46.6ms
# Speed: 0.9ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 640)
# 20
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig4.jpg: 512x640 21 labels, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig5.jpg: 640x640 3 labels, 103.7ms
# Speed: 2.5ms preprocess, 103.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig6.jpg: 224x640 2 labels, 63.5ms
# Speed: 1.0ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 640)
# 16
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig7.jpg: 608x640 3 labels, 79.3ms
# Speed: 2.3ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# Subfigure count mismatch: 3 detected, 16 expected
# 1
# RNA sequencing data from patients carrying SRPK3 truncating variants (LII:1, DII:1 and YII:3) were analyzed for SRPK3 expression between patient (n = 3) and control (n = 6) samples. Counts per million (CPM) values were normalized by gene length. The boxes represent the first and third quartiles (25% and 75% percentile) with the center line at the median value. The whiskers extend from the hinge to the furthest value not beyond 1.5 times the interquartile range from the hinge. Differential expression was performed in edgeR using a two-sided exact test, with no adjustment for multiple comparisons. Uncorrected P-value = 7.106 × 10−11.
# 16
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig9.jpg: 576x640 2 labels, 86.7ms
# Speed: 2.1ms preprocess, 86.7ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
# Subfigure count mismatch: 2 detected, 16 expected
# 1
# TTN truncating variants (nonsense, splice sites and frameshift) are shown in black and missense variants in green. No missense variants in TTN exons 344 or 364, associated with HMERF and tibial muscular dystrophy, respectively, were found. TTN variants were located mainly in the A-band and I-band; however, no clustering was observed. Two frameshift variants occurred in meta transcript only exons (in pink).
# 1
# RNA sequencing data from SRPK3/TTN myopathy patients (LII:1, DII:1 and YII:3) were analyzed for TTN expression between patient (n = 3) and control (n = 6) samples. Counts per million (CPM) values were normalized by gene length. The boxes represent the first and third quartiles (25% and 75% percentile) with the center line at the median value. The whiskers extend from the hinge to the furthest value not beyond 1.5 times the interquartile range from the hinge. Differential expression was performed in edgeR using a two-sided exact test, with no adjustment for multiple comparisons. Uncorrected P-value = 0.0008015. This was likely not due to nonsense-mediated mRNA decay, as there was no evidence of allele-specific expression at any of the heterozygous TTN loci examined.
# 1
# Comparison between the number of TTNtv (stop gain, splice sites and frameshift variants) in the SRPK3/TTN myopathy families (n = 25) and three cohorts of patients with genetically confirmed forms of limb girdle muscular dystrophy: LGMD-R1 (n = 170), LGMD-R2 (n = 94) and LGMD-R12 (n = 56). A Fisher’s test (two-sided, with no adjustment for multiple comparisons), following the proposal of Agresti and Coull to add two successes and two failures to each data set was calculated. P-values: (*) = 6.13 × 10−19, (**) = 9.18 × 10−17 and (***) = 4.89 × 10−12.
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig13.jpg: 640x640 2 labels, 98.5ms
# Speed: 2.6ms preprocess, 98.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig14.jpg: 448x640 6 labels, 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937387_Fig15.jpg: 256x640 2 labels, 60.7ms
# Speed: 1.1ms preprocess, 60.7ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 640)
# 1
# The table shows the top enriched GO terms from the comparisons of srpk3−/−; ttn.1+/− and srpk3−/−; ttn.1+/+ embryos to wild-type (P < 0.001 in one of the comparisons). The topGO P-value columns show the P-value from the enrichment test for each comparison. The dots in the number of DE genes columns represent the number of DE genes annotated to the term that appear either in srpk3−/−; ttn.1+/− alone (blue), srpk3−/−; ttn.1+/+ alone (red) or in both (purple). For most GO terms, most of the DE genes causing the enrichment are shared between both lists. GO term enrichment was done using the topGO package using a one-sided Fisher’s exact test without adjustment for multiple testing.
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10937381_Fig1.jpg: 608x640 4 labels, 86.8ms
# Speed: 2.3ms preprocess, 86.8ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
# 1
# Contact matrices displaying in vivo13 and in vitro Micro-C data with corresponding insulation scores and nucleosome occupancy profiles (MNase-seq) for three genomic regions. Gene (arrows) and sequence composition annotation are shown at the top (A, adenine; T, thymine). In vivo19 and in vitro ChIP–seq data for Abf1 (blue) and Reb1 (red) are shown below the in vivo data. Chromatin used for in vitro Micro-C was incubated with the indicated remodeler and the TFs Abf1 and Reb1 or with the TFs only. Strongly insulating boundaries are labeled with gray dots. Micro-C data are plotted as log10 interaction counts at 40 bp resolution. Insulation scores are calculated at 80 bp resolution with three different sliding windows.
# 6
#
# ...
# 4
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260404_Fig12.jpg: 320x640 4 labels, 76.0ms
# Speed: 1.5ms preprocess, 76.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# Subfigure count mismatch: 3 detected, 4 expected
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260404_Fig13.jpg: 640x608 6 labels, 94.0ms
# Speed: 2.4ms preprocess, 94.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 608)
# 7
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260403_Fig1.jpg: 640x544 7 labels, 64.0ms
# Speed: 2.2ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260403_Fig2.jpg: 640x544 4 labels, 63.3ms
# Speed: 2.2ms preprocess, 63.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
# Subfigure count mismatch: 4 detected, 2 expected
# 1
# Distribution of EDU and VNR scores for KDM5B PTV carriers in the UKB. ClinVar probably pathogenic variants for IDD (MIM 618109) were annotated. Samples with inpatient ICD-10 records of psychiatric (SCZ, BD, depression, substance use disorder or anxiety and stress disorders), neurodegenerative and neurodevelopmental disorders were annotated. Phenotypes were residualized by sex, age, age2, sex by age, sex by age2, top 20 principal components and recruitment centers and were rank-based inverse-normal transformed. The blue (for EDU) and red (for VNR) lines represent fitted locally estimated scatterplot smoothing (LOESS) regression on standardized, residualized phenotypes. The gray bands represent 95% CIs for the fitted LOESS regression.
# 3
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260403_Fig4.jpg: 640x640 4 labels, 74.0ms
# Speed: 2.4ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260403_Fig5.jpg: 640x544 2 labels, 79.2ms
# Speed: 2.4ms preprocess, 79.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 544)
# 1
# FEV1 Z-score is Inverted GLI 2012 z-score for FEV1. Phenotypes were grouped and color-coded from left to right in the following categories: biomarker; composite phenotypes; family history; ICD-10 cause of death, ICD-10 congenital malformations; deformations and chromosomal abnormalities; ICD-10 diseases of the circulatory system; ICD-10 diseases of the digestive system; ICD-10 diseases of the eye and adnexa; ICD-10 diseases of the genitourinary system; ICD-10 diseases of the musculoskeletal system and connective tissue; ICD-10 diseases of the nervous system; ICD-10 diseases of the respiratory system; ICD-10 diseases of the skin and subcutaneous tissue; ICD-10 endocrine, nutritional and metabolic diseases; ICD-10 mental, behavioral and neurodevelopmental disorders; ICD-10 neoplasms; ICD-10 pregnancy, childbirth and the puerperium; ICD-10 symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified; operation code; self-reported illness: cancer; self-reported illness: non−cancer; self-reported medication. Bonferroni corrected p-value (two-sided t-test) significance threshold was 0.05/3150 = 1.59×10−5.
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260403_Fig7.jpg: 640x576 2 labels, 87.8ms
# Speed: 2.2ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# 1
# ClinVar pathogenic/likely pathogenic variants for epileptic encephalopathy (MIM 617106) and/or type 2 episodic ataxia (MIM 108500) was annotated. Samples with inpatient ICD-10 (International Classification of Diseases version-10) records of psychiatric (schizophrenia, bipolar disorder, depression, substance use disorder and/or anxiety and stress disorders), neurodegenerative and neurodevelopmental disorders were annotated. Phenotypes were residualized by sex, age, age2, sex by age interaction, sex by age2 interaction, top 20 PCs, and recruitment center and inverse rank-based normal transformed. The blue line (for EDU) and red line (for VNR) represent fitted loess regression on standardized, residualized phenotypes. The gray bands represent 95% confidence intervals for the fitted loess regression.
# 1
# An intermediate effect on cranial length (additive genotype effect two-sided P = 0.0268) and height (additive genotype effect two-sided P = 0.0056) is detected in Kdm5b+/− mice, but not in cranial width (additive genotype effect two-sided P = 0.3090). For the boxplot, the center line represents the median, the box limits represent the IQR, and the whiskers indicate the minimum and maximum values. A fully penetrant transitional vertebrae phenotype seen in Kdm5b−/− mice (N = 21) is observed at a lower frequency in Kdm5b+/− mice (N = 40, Fisher’s exact test vs Kdm5b+/+ two-sided P = 0.0189).
# 1
# Log2-fold change of differentially expressed genes plotted for Kdm5b+/− (y-axis) and Kdm5b−/− (x-axis) mice across embryonic and adult brain tissues as indicated. There is a strong correlation between direction of change in expression in both mutant genotypes (robust linear regression line and slope shown in red).
# 1
# Regional plot of educational attainment GWAS association test results were generated around top independent SNP rs10798888. Additional associations from GWAS catalog were annotated with the associated phenotypes in the regional plot. EDU and VNR score for ADGRB2 PTV carriers in UKB were plotted (both phenotypes were residualized by sex, age, age2, sex by age, sex by age2, top 20 PCs and recruitment centers and were inverse rank-based normal transformed). Samples with inpatient ICD-10 (International Classification of Diseases version-10) records of psychiatric, neurodegenerative, and neurodevelopmental disorders were annotated. The blue line (for EDU) and red line (for VNR) represent fitted loess regression on standardized, residualized phenotypes. The gray bands represent 95% confidence intervals for the fitted loess regression.
# 1
# Regional plot of cognitive function GWAS association test results were generated for top independent SNP rs5751191 and the extended LD region. Additional associations from GWAS catalog were annotated with the associated phenotypes in the regional plot. Number of PTV carriers and gene-based PTV burden association p-value were extracted for genes in the region.
# 1
# Unrelated UKB EUR samples were included for this analysis (N = 318,844 for EDU, 319,536 for RT, and 128,812 for VNR). Genes were stratified by elevated expression in brain tissue (2,587 genes), elevated expression in other tissues but also expressed in brain (5,298 genes) and no tissue specific expression (8,342 genes). Number of genes included in the burden is annotated for each set. Data are presented in effect size estimates (β) with 95% confidence intervals.
# 1
# The impact of cognitive function polygenic score (PRS) and carrier status of PTV and/or damaging missense variants (MPC > 2) in LoF intolerant genes (pLI > 0.9) on a) EDU and b) VNR. EDU and VNR were residualized by sex, age, age2, sex by age, sex by age2, top 20 PCs and recruitment centers and inverse rank-based normal transformed. Median of educational attainment was calculated for individuals stratified by PRS quantiles (in 2% groups) and PTV and/or damaging missense variant carrier status. The blue and red lines represent fitted linear regressions for standardized, residualized phenotypes by PRS percentile groups, stratified by rare coding variant carrier status. The gray bands represent 95% confidence intervals for each of the fitted linear regression.
# 5
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260399_Fig1.jpg: 544x640 5 labels, 75.7ms
# Speed: 2.1ms preprocess, 75.7ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260399_Fig2.jpg: 544x640 2 labels, 83.2ms
# Speed: 2.0ms preprocess, 83.2ms inference, 2.2ms postprocess per image at shape (1, 3, 544, 640)
# 6
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260399_Fig3.jpg: 480x640 6 labels, 85.7ms
# Speed: 2.1ms preprocess, 85.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# 1
# Seedling inoculations on the Lr58-carrying wheat line TA5605 (near isogenic line in the genetic background of bread wheat line WL711) and the Lr9-containing bread wheat line ThatcherLr9. Images were taken 12 days after inoculation with seven different Pt isolates. Isolates B9414, 93012, 96237, 95012, 94015, and 96007 are avirulent on Lr9. Pt isolate MNPSD is virulent on Lr9. Scale bar = 1 cm.
# 1
# TA5605 M3 mutants (a) and M2 mutants (b) were inoculated with P. triticina isolate B9414. Shown are leaves 12 days after inoculation. Spt = Suceptible to Puccinia triticina. Scale bar = 1 cm.
# 1
# Shown are representatives images of an F2 population derived from a cross between ThatcherLr9 and Avocet S inoculated with the avirulent P. triticina isolate B9414. M-VWA represents a PCR marker developed from the WTK6-vWA coding sequence. SCS5550 represents a PCR marker reported to be linked to Lr9. Markers were genotyped as present (+) or absent (-). R = resistant, S = susceptible. Images were taken 12 days after inoculation. Scale bar = 1 cm.
# 1
# Shown are representative images of an F2 population derived from a cross between TA5605 and Avocet S inoculated with the avirulent P. triticina isolate 96007. M-VWA represents a PCR marker developed from the WTK6-vWA coding sequence. Xncw-Lr58-1 represents a PCR marker reported to be linked with Lr58. Markers were genotyped as present (+) or absent (-). R = resistant, S = susceptible. Images were taken 12 days after inoculation. Scale bar = 1 cm.
# 1
# The kinase 1 domain is surrounded by a red box, kinase 2 by a brown box, the vWA domain by a purple box, and the Vwaint domain by a blue box. Roman numerals represent conserved kinase subdomains. Letters above the Lr9 amino acid sequence represent EMS-induced amino acid substitutions. Letters in gray were found in partially susceptible mutants, indicating a knock-down of protein function. ‘*’ indicates mutations causing a premature stop codon. Black triangles = ATP binding site; red triangles = key conserved residues, black asterisks = putative substrate binding site, blue squares = residue determining RD and non-RD kinases, orange triangle = glutamic acid to aspartic acid substitution in subdomain III of kinase 2.
# 1
# Rectangular boxes in red and brown colors represent kinase domains belonging to the LRR_8B (cysteine rich kinases) and LRR_3 (leucine-rich-repeat receptor kinase subfamily 3) families. Bent ovals in blue, purple and orange represent vWA domains. Blue dots indicate kinase vWA gene fusion events. Numbers in brackets represent the maximum number of genes found in a given accession of each species.
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260399_Fig10.jpg: 608x640 2 labels, 118.0ms
# Speed: 2.3ms preprocess, 118.0ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260399_Fig11.jpg: 352x640 4 labels, 135.6ms
# Speed: 1.6ms preprocess, 135.6ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
# Subfigure count mismatch: 3 detected, 2 expected
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260398_Fig1.jpg: 384x640 2 labels, 98.5ms
# Speed: 1.7ms preprocess, 98.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260398_Fig2.jpg: 448x640 2 labels, 76.1ms
# Speed: 1.8ms preprocess, 76.1ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260398_Fig3.jpg: 320x640 2 labels, 72.9ms
# Speed: 1.4ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# 2
#
# image 1/1 /Users/etowah/projects/PMC-figure-downloader/img/10260398_Fig4.jpg: 288x640 2 labels, 54.3ms
# Speed: 1.3ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 640)
# [['10937393', 'Fig3'], ['10937393', 'Fig12'], ['10937382', 'Fig10'], ['10937379', 'Fig9'], ['10937375', 'Fig3'], ['10937375', 'Fig10'], ['10937375', 'Fig12'], ['10937375', 'Fig14'], ['10864188', 'Fig12'], ['10864188', 'Fig13'], ['10864188', 'Fig14'], ['10864183', 'Fig8'], ['10864183', 'Fig10'], ['10864183', 'Fig11'], ['10864183', 'Fig13'], ['10864174', 'Fig3'], ['10937399', 'Fig4'], ['10937392', 'Fig4'], ['10937392', 'Fig13'], ['10937392', 'Fig16'], ['10937392', 'Fig18'], ['10937387', 'Fig2'], ['10937387', 'Fig7'], ['10937387', 'Fig9'], ['10937381', 'Fig14'], ['10786726', 'Fig3'], ['10786726', 'Fig7'], ['10786715', 'Fig11'], ['10786714', 'Fig1'], ['10786714', 'Fig3'], ['10786714', 'Fig6'], ['10703699', 'Fig13'], ['10703699', 'Fig15'], ['10703699', 'Fig16'], ['10703693', 'Fig7'], ['10703693', 'Fig9'], ['10703692', 'Fig8'], ['10703692', 'Fig13'], ['10703692', 'Fig16'], ['10703688', 'Fig6'], ['10703688', 'Fig15'], ['10703679', 'Fig2'], ['10703679', 'Fig7'], ['10703679', 'Fig9'], ['10703679', 'Fig10'], ['10703679', 'Fig13'], ['10703676', 'Fig4'], ['10786727', 'Fig6'], ['10786727', 'Fig10'], ['10786727', 'Fig11'], ['10786727', 'Fig12'], ['10786727', 'Fig13'], ['10786727', 'Fig15'], ['10786724', 'Fig1'], ['10786724', 'Fig9'], ['10786720', 'Fig7'], ['10786720', 'Fig11'], ['10786716', 'Fig4'], ['10703697', 'Fig3'], ['10703696', 'Fig10'], ['10703691', 'Fig4'], ['10703691', 'Fig7'], ['10703691', 'Fig14'], ['10703686', 'Fig2'], ['10703686', 'Fig3'], ['10703686', 'Fig5'], ['10703686', 'Fig7'], ['10703684', 'Fig3'], ['10703684', 'Fig4'], ['10703684', 'Fig5'], ['10703684', 'Fig6'], ['10703684', 'Fig7'], ['10703684', 'Fig8'], ['10703684', 'Fig9'], ['10703684', 'Fig10'], ['10703684', 'Fig11'], ['10703684', 'Fig12'], ['10632150', 'Fig4'], ['10632150', 'Fig12'], ['10562256', 'Fig10'], ['10562256', 'Fig15'], ['10562255', 'Fig5'], ['10562255', 'Fig15'], ['10484791', 'Fig2'], ['10484791', 'Fig17'], ['10484789', 'Fig15'], ['10484789', 'Fig16'], ['10412453', 'Fig4'], ['10412453', 'Fig9'], ['10412453', 'Fig10'], ['10412453', 'Fig14'], ['10335940', 'Fig3'], ['10335940', 'Fig4'], ['10335940', 'Fig5'], ['10335940', 'Fig7'], ['10335940', 'Fig8'], ['10335940', 'Fig10'], ['10335940', 'Fig11'], ['10335940', 'Fig13'], ['10335940', 'Fig14'], ['10335940', 'Fig16'], ['10335940', 'Fig17'], ['10335940', 'Fig18'], ['10335939', 'Fig2'], ['10335939', 'Fig4'], ['10335939', 'Fig6'], ['10335939', 'Fig15'], ['10335937', 'Fig1'], ['10335937', 'Fig2'], ['10335937', 'Fig4'], ['10335937', 'Fig6'], ['10335937', 'Fig7'], ['10335937', 'Fig9'], ['10335937', 'Fig10'], ['10335937', 'Fig12'], ['10335937', 'Fig14'], ['10335937', 'Fig15'], ['10335936', 'Fig6'], ['10335936', 'Fig14'], ['10335934', 'Fig4'], ['10335934', 'Fig5'], ['10335933', 'Fig1'], ['10335933', 'Fig5'], ['10335929', 'Fig4'], ['10632151', 'Fig9'], ['10632151', 'Fig10'], ['10632151', 'Fig14'], ['10632151', 'Fig15'], ['10632143', 'Fig1'], ['10632132', 'Fig3'], ['10260402', 'Fig4'], ['10260402', 'Fig5'], ['10260402', 'Fig7'], ['10260402', 'Fig10'], ['10260402', 'Fig11'], ['10260400', 'Fig1'], ['10260400', 'Fig15'], ['10260397', 'Fig1'], ['10260397', 'Fig3'], ['10260397', 'Fig6'], ['10562254', 'Fig9'], ['10562254', 'Fig10'], ['10562254', 'Fig13'], ['10484788', 'Fig3'], ['10484787', 'Fig6'], ['10484787', 'Fig14'], ['10484787', 'Fig16'], ['10484787', 'Fig17'], ['10484786', 'Fig5'], ['10484784', 'Fig5'], ['10484784', 'Fig6'], ['10484784', 'Fig7'], ['10484784', 'Fig8'], ['10412459', 'Fig13'], ['10412459', 'Fig15'], ['10412459', 'Fig17'], ['10335938', 'Fig2'], ['10335938', 'Fig4'], ['10335938', 'Fig5'], ['10335938', 'Fig9'], ['10335938', 'Fig16'], ['10260405', 'Fig7'], ['10260404', 'Fig2'], ['10260404', 'Fig9'], ['10260404', 'Fig12'], ['10260403', 'Fig2'], ['10260399', 'Fig11']]
